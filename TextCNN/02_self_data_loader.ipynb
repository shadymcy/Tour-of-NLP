# %%
import numpy as np
import pandas as pd
import jieba
from collections import defaultdict
import torch
from operator import add
from functools import reduce
from collections import Counter
from torch.utils.data import DataLoader
from icecream import ic

# %%
from self_embedding import get_embedding
# Out:
# load embedding file: dataset/sgns.weibo.word.bz2 end!
# 函数注释 {'ham': 42, 'eggs': <class 'int'>, 'return': 'Nothing to see here'}
# 参数值打印 www spam
# <class 'str'> <class 'str'>
# <enumerate object at 0x000001702E2D18C0>
# 5 Spring
# 6 Summer
# 7 Fall
# 8 Winter

# %%
def add_with_print(all_corpus):
    add_with_print.i = 0
    def _wrap(a, b):
        add_with_print.i += 1  ##这里不能用++
        print('{}/{}'.format(add_with_print.i, len(all_corpus)),end=' ')
        return a+b
    return _wrap

# %%
def get_all_vocabulary(train_file_path, vocab_size):
    CUT, SENTENCE = 'cut', 'sentence'
    
    corpus = pd.read_csv(train_file_path)
    corpus[CUT] = corpus[SENTENCE].apply(lambda s:' '.join(list(jieba.cut(s))))
    sentence_counters = map(Counter, map(lambda s:s.split(),corpus[CUT].values))
    chose_words = reduce(add_with_print(corpus), sentence_counters).most_common(vocab_size)
    
    return [w for w,_ in chose_words]

# %% [markdown]
# ## 字典的get方法
# ### 语法
# get()方法语法：
#
# dict.get(key, value)
# ### 参数
# key -- 字典中要查找的键。
#
# value -- 可选，如果指定键的值不存在时，返回该默认值。
# ### 返回值
# 返回指定键的值，如果键不在字典中返回默认值 None 或者设置的默认值。

# %%
def tokenizer(sentence, vocab: dict):
    UNK = 1
    ids = [vocab.get(word, UNK) for word in jieba.cut(sentence)]
    
    return ids

# %% [markdown]
# 字典(Dictionary) items() 函数以列表返回可遍历的(键, 值) 元组数组。

# %%
def get_train_data(train_file, vocab2ids):
    val_ratio = 0.2
    content = pd.read_csv(train_file)
    num_val = int(len(content) * val_ratio)
    
    LABEL, SENTENCE = 'label', 'sentence'
    
    labels = content[LABEL].values
    content['input_ids'] = content[SENTENCE].apply(lambda s:' '.join([str(_id) for _id in tokenizer(s, vocab2ids)]))
    sentence_ids = np.array([[int(_id) for _id in v.split()] for v in content['input_ids'].values])
    
    ids = np.random.choice(range(len(content)), size = len(content))
    ## shuffle ids
    
    train_ids = ids[num_val:]
    val_ids = ids[:num_val]
    
    X_train,y_train = sentence_ids[train_ids], labels[train_ids]
    X_val, y_val = sentence_ids[val_ids], labels[val_ids]
    
    label2id = {label: i for i, label in enumerate(np.unique(y_train))}
    id2label = {i : label for label, i in label2id.items()}
    y_train = torch.tensor([label2id[y] for  y in y_train], dtype = torch.long)
    y_val = torch.tensor([label2id[y] for y in y_val], dtype = torch.long)
    
    return X_train, y_train, X_val, y_val, label2id, id2label

# %% [markdown]
# #  DataLoader
# 做成的数据集放入Data.DataLoader中，可以生成一个迭代器，从而我们可以方便的进行批处理。
#
# ## 介绍一下DataLoader(object)的参数：
#
# dataset：Dataset类型，从其中加载数据
#
# batch_size：int，可选。每个batch加载多少样本
#
# shuffle：bool，可选。为True时表示在每个epoch对数据进行打乱
#
# sampler：Sampler，可选。从数据集中采样样本的方法。
#
# num_workers：int，可选。加载数据时使用多少子进程。默认值为0，表示在主进程中加载数据。
#
# collate_fn：callable，可选。
#
# pin_memory：bool，可选
#
# drop_last：bool，可选。True表示如果最后剩下不完全的batch,丢弃。False表示不丢弃

# %% [markdown]
# ## zip() 函数
# 用于将可迭代的对象作为参数，将对象中对应的元素打包成一个个元组，然后返回由这些元组组成的列表。
#
# 如果各个迭代器的元素个数不一致，则返回列表长度与最短的对象相同，利用 * 号操作符，可以将元组解压为列表。

# %% [markdown]
# ### zip举例

# %%
for x, y in zip([1,2,3], [11,22,33]):
    print(x,y)
# Out:
# 1 11
# 2 22
# 3 33

# %% [markdown]
# ## 特别注意：
# 1.这里额外定义了一个collate_fn 并用在了build_dataloader中
# 如果没有用collate_fn限制会出现
#
# RuntimeError: each element in list of batch should be of equal size
#
# 没有用collate_fn的解决方案： 在if __name__ == '__main__':中设置batch_size=1
#
# 2.在运行if __name__ == '__main__':中出现了
#
# Caught TypeError in DataLoader worker process 0.
#
# 解决方案：把build_dataloader 中num_workers = 0 （原本为4）
#
# num_workers = 4的方案暂时没有解决

# %%
def collate_fn(batch):
    #  batch是一个列表，其中是一个一个的元组，每个元组是dataset中_getitem__的结果
    batch = list(zip(*batch))
    labels = torch.tensor(batch[1], dtype=torch.int32)
    texts = batch[1]
    del batch  
    return labels, texts

# %%
def build_dataloader(X_train, y_train, X_val, y_val, batch_size):
    train_dataloader = DataLoader([(x,y) for x, y in zip(X_train, y_train)], batch_size = batch_size, num_workers = 0, shuffle = True, collate_fn= collate_fn)
    val_dataloader = DataLoader([(x,y) for x, y in zip(X_val, y_val)], batch_size = batch_size, num_workers = 0, shuffle = True,collate_fn = collate_fn)
    
    return train_dataloader, val_dataloader

# %% [markdown]
# ### isinstance() 函数来判断一个对象是否是一个已知的类型

# %% [markdown]
# ### open (xxx,f)以只读方式打开文件。文件的指针将会放在文件的开头。这是默认模式。

# %% [markdown]
# ## if __name__ == '__main__':的作用
# 一个python文件通常有两种使用方法，第一是作为脚本直接执行，第二是 import 到其他的 python 脚本中被调用（模块重用）执行。因此 if __name__ == 'main': 的作用就是控制这两种情况执行代码的过程，在 if __name__ == 'main': 下的代码只有在第一种情况下（即文件作为脚本直接执行）才会被执行，而 import 到其他脚本中是不会被执行的。
#
# 具体情况参照：https://blog.csdn.net/heqiang525/article/details/89879056

# %%
if __name__ == '__main__':
    #vocab_size = 10000
    #vocabulary = get_all_vocabulary(train_file_path='dataset/train.csv', vocab_size=vocab_size)
    #assert isinstance(vocabulary, list)
    #assert isinstance(vocabulary[0], str)
    #assert len(vocabulary) <= vocab_size
    
    ## with open('dataset/vocabulary.txt','w', encoding='utf-8') as f:
        ## for word in vocabulary:
            ## f.write(word + '\n')
    ## print('write vocabulary is finished!')
    ## 生成vocabulary.txt  生成完后可以不用执行
    f = open('dataset/vocabulary.txt', 'r', encoding='utf-8')
    vocabulary = f.readlines()
    vocabulary = [v.strip() for v in vocabulary]
    
    embedding, token2id, vocab_size = get_embedding(set(vocabulary))
    
    X_train, y_train, X_val, y_val, label2id, id2label = get_train_data('dataset/train.csv', vocab2ids = token2id)
    
    print(X_train, y_train, X_val, y_val, label2id, id2label)
    
    train_loader, val_loader = build_dataloader(X_train, y_train, X_val, y_val, batch_size=128)
    
    for i, (x, y) in enumerate(train_loader):
        ic(x)
        ic(y)
        if i > 10: break
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 195202/195202 [00:02<00:00, 69641.16it/s]
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\90392\AppData\Local\Temp\jieba.cache
# Loading model cost 0.540 seconds.
# Prefix dict has been built successfully.
# C:\Users\90392\AppData\Local\Temp/ipykernel_4424/2251427330.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   sentence_ids = np.array([[int(_id) for _id in v.split()] for v in content['input_ids'].values])
# [list([1, 24, 1, 61, 4, 439, 1439, 24, 1, 300, 946, 4, 1, 5534, 350, 1, 197, 2232, 315])
#  list([877, 620, 936, 1397, 8989, 1, 4, 4121, 10, 21, 232, 1, 7])
#  list([6519, 10, 4611, 1, 3216, 4, 6897, 1, 4, 341, 85, 6295, 17]) ...
#  list([1353, 4301, 6363, 5028, 191, 762, 4, 6538, 208, 760, 281, 1278, 4, 4877, 6363, 1159, 1424, 8])
#  list([256, 743, 7513, 4290, 4, 493, 1, 85, 2855, 298, 14, 719, 4, 7513, 4290, 221, 2855, 298, 14, 115, 1109, 92, 17])
#  list([3445, 1258, 4, 1, 2852, 5, 164])] tensor([ 6,  4,  1,  ...,  9, 11, 10]) [list([4970, 890, 5066, 1286, 946, 4, 574, 1, 169, 7456, 7, 1499, 81, 667, 3574, 4087, 2582, 6939, 7])
#  list([31, 73, 2718, 5, 4906, 1047, 644, 1])
#  list([4556, 141, 8647, 8, 1, 4, 4208, 5817, 1703, 3027, 4, 4027, 31, 341, 4983, 17])
#  ...
#  list([1, 356, 1, 5, 25, 4, 5148, 90, 8, 4375, 2321, 1, 4, 1, 216, 1, 6727, 7])
#  list([107, 13, 1, 91, 3996, 17, 1243, 1, 2008, 1436, 6430, 1609, 31, 7])
#  list([1, 3176, 5528, 10, 1, 797, 158, 4633, 154, 1861, 4, 1, 2162, 95, 409, 26, 15, 90])] tensor([ 5,  4,  9,  ..., 10,  7,  8]) {100: 0, 101: 1, 102: 2, 103: 3, 104: 4, 106: 5, 107: 6, 108: 7, 109: 8, 110: 9, 112: 10, 113: 11, 114: 12, 115: 13, 116: 14} {0: 100, 1: 101, 2: 102, 3: 103, 4: 104, 5: 106, 6: 107, 7: 108, 8: 109, 9: 110, 10: 112, 11: 113, 12: 114, 13: 115, 14: 116}
# ic| x: tensor([ 8, 14,  6,  8, 10, 10,  0, 11, 13,  4,  9,  8, 13, 11,  6,  4, 13, 14,
#                 7, 10,  3,  8, 10,  7,  3,  9,  1,  8, 11,  2,  2,  6, 14,  2, 10,  1,
#                10,  8,  4, 13,  1,  6,  7, 14,  3, 14,  6, 13,  2,  8, 11,  6,  6, 14,
#                 9,  6,  7,  4,  4,  6,  4,  2,  4,  6,  9,  2,  9,  4,  2, 11,  6,  3,
#                 7, 13, 11,  3,  8,  4,  8,  4,  4,  3,  9,  4, 13,  0, 13,  8,  1,  3,
#                 7,  1,  8,  4,  2, 11, 12,  5,  2, 14,  1,  6, 11,  1, 14, 11,  8,  6,
#                 4,  1,  5,  4,  2,  6,  8,  7,  1, 11, 10,  2,  0,  8,  3,  4, 11,  1,
#                 5,  2], dtype=torch.int32)
# ic| y: (tensor(8),
#         tensor(14),
#         tensor(6),
#         tensor(8),
#         tensor(10),
#         tensor(10),
#         tensor(0),
#         tensor(11),
#         tensor(13),
#         tensor(4),
#         tensor(9),
#         tensor(8),
#         tensor(13),
#         tensor(11),
#         tensor(6),
#         tensor(4),
#         tensor(13),
#         tensor(14),
#         tensor(7),
#         tensor(10),
#         tensor(3),
#         tensor(8),
#         tensor(10),
#         tensor(7),
#         tensor(3),
#         tensor(9),
#         tensor(1),
#         tensor(8),
#         tensor(11),
#         tensor(2),
#         tensor(2),
#         tensor(6),
#         tensor(14),
#         tensor(2),
#         tensor(10),
#         tensor(1),
#         tensor(10),
#         tensor(8),
#         tensor(4),
#         tensor(13),
#         tensor(1),
#         tensor(6),
#         tensor(7),
#         tensor(14),
#         tensor(3),
#         tensor(14),
#         tensor(6),
#         tensor(13),
#         tensor(2),
#         tensor(8),
#         tensor(11),
#         tensor(6),
#         tensor(6),
#         tensor(14),
#         tensor(9),
#         tensor(6),
#         tensor(7),
#         tensor(4),
#         tensor(4),
#         tensor(6),
#         tensor(4),
#         tensor(2),
#         tensor(4),
#         tensor(6),
#         tensor(9),
#         tensor(2),
#         tensor(9),
#         tensor(4),
#         tensor(2),
#         tensor(11),
#         tensor(6),
#         tensor(3),
#         tensor(7),
#         tensor(13),
#         tensor(11),
#         tensor(3),
#         tensor(8),
#         tensor(4),
#         tensor(8),
#         tensor(4),
#         tensor(4),
#         tensor(3),
#         tensor(9),
#         tensor(4),
#         tensor(13),
#         tensor(0),
#         tensor(13),
#         tensor(8),
#         tensor(1),
#         tensor(3),
#         tensor(7),
#         tensor(1),
#         tensor(8),
#         tensor(4),
#         tensor(2),
#         tensor(11),
#         tensor(12),
#         tensor(5),
#         tensor(2),
#         tensor(14),
#         tensor(1),
#         tensor(6),
#         tensor(11),
#         tensor(1),
#         tensor(14),
#         tensor(11),
#         tensor(8),
#         tensor(6),
#         tensor(4),
#         tensor(1),
#         tensor(5),
#         tensor(4),
#         tensor(2),
#         tensor(6),
#         tensor(8),
#         tensor(7),
#         tensor(1),
#         tensor(11),
#         tensor(10),
#         tensor(2),
#         tensor(0),
#         tensor(8),
#         tensor(3),
#         tensor(4),
#         tensor(11),
#         tensor(1),
#         tensor(5),
#         tensor(2))
# ic| x: tensor([ 2,  4,  6,  4, 11,  2,  3,  8,  0,  5, 11,  6, 13,  1, 10,  1,  6,  4,
#                13, 11,  7,  7,  1,  8,  9,  2,  9,  7,  2,  1,  3,  4,  4,  3,  8,  4,
#                 3,  2, 10,  7, 11,  8, 10,  3, 10,  1, 13, 13,  4,  0,  7,  8,  4,  3,
#                 9, 10, 13,  2,  6,  7, 11,  5,  4,  2, 14,  7,  2, 14, 10,  8,  3,  6,
#                14, 14,  4, 10, 11,  6,  5,  4,  0,  1,  8,  8,  6,  1,  2, 14, 14,  8,
#                13,  3,  9,  3,  7,  5, 10,  2,  8, 10, 13,  6,  7,  4, 10,  8,  3,  8,
#                 7,  1,  7,  5,  8,  9, 14,  8, 14,  9, 11,  8,  3,  9,  8, 13,  3,  4,
#                 9,  2], dtype=torch.int32)
# ic| y: (tensor(2),
#         tensor(4),
#         tensor(6),
#         tensor(4),
#         tensor(11),
#         tensor(2),
#         tensor(3),
#         tensor(8),
#         tensor(0),
#         tensor(5),
#         tensor(11),
#         tensor(6),
#         tensor(13),
#         tensor(1),
#         tensor(10),
#         tensor(1),
#         tensor(6),
#         tensor(4),
#         tensor(13),
#         tensor(11),
#         tensor(7),
#         tensor(7),
#         tensor(1),
#         tensor(8),
#         tensor(9),
#         tensor(2),
#         tensor(9),
#         tensor(7),
#         tensor(2),
#         tensor(1),
#         tensor(3),
#         tensor(4),
#         tensor(4),
#         tensor(3),
#         tensor(8),
#         tensor(4),
#         tensor(3),
#         tensor(2),
#         tensor(10),
#         tensor(7),
#         tensor(11),
#         tensor(8),
#         tensor(10),
#         tensor(3),
#         tensor(10),
#         tensor(1),
#         tensor(13),
#         tensor(13),
#         tensor(4),
#         tensor(0),
#         tensor(7),
#         tensor(8),
#         tensor(4),
#         tensor(3),
#         tensor(9),
#         tensor(10),
#         tensor(13),
#         tensor(2),
#         tensor(6),
#         tensor(7),
#         tensor(11),
#         tensor(5),
#         tensor(4),
#         tensor(2),
#         tensor(14),
#         tensor(7),
#         tensor(2),
#         tensor(14),
#         tensor(10),
#         tensor(8),
#         tensor(3),
#         tensor(6),
#         tensor(14),
#         tensor(14),
#         tensor(4),
#         tensor(10),
#         tensor(11),
#         tensor(6),
#         tensor(5),
#         tensor(4),
#         tensor(0),
#         tensor(1),
#         tensor(8),
#         tensor(8),
#         tensor(6),
#         tensor(1),
#         tensor(2),
#         tensor(14),
#         tensor(14),
#         tensor(8),
#         tensor(13),
#         tensor(3),
#         tensor(9),
#         tensor(3),
#         tensor(7),
#         tensor(5),
#         tensor(10),
#         tensor(2),
#         tensor(8),
#         tensor(10),
#         tensor(13),
#         tensor(6),
#         tensor(7),
#         tensor(4),
#         tensor(10),
#         tensor(8),
#         tensor(3),
#         tensor(8),
#         tensor(7),
#         tensor(1),
#         tensor(7),
#         tensor(5),
#         tensor(8),
#         tensor(9),
#         tensor(14),
#         tensor(8),
#         tensor(14),
#         tensor(9),
#         tensor(11),
#         tensor(8),
#         tensor(3),
#         tensor(9),
#         tensor(8),
#         tensor(13),
#         tensor(3),
#         tensor(4),
#         tensor(9),
#         tensor(2))
# ic| x: tensor([ 8,  9,  4,  8, 11,  8, 11, 10,  9,  4,  2,  4,  4,  8,  8, 13,  5, 13,
#                14,  2,  8,  6,  4, 14,  8,  1,  3,  8,  3,  3,  9,  3,  2,  4,  0,  1,
#                11,  9,  9,  8, 10,  2, 13,  7,  4, 11,  2,  8,  5,  8,  4,  1, 10,  6,
#                 9,  3,  2,  7, 10,  6, 14,  8, 10, 13,  4,  3,  7, 11, 10,  3,  9, 13,
#                 3, 14,  3,  7, 13, 13, 10, 10,  0, 11,  3,  2, 13,  7, 10, 13,  4,  9,
#                11,  8,  5,  6,  1,  7,  1,  1, 11,  6, 10,  6,  2,  1,  3,  4,  9,  9,
#                 8, 14,  9,  6,  9,  8, 10,  5,  2,  4,  3,  9,  3,IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# ,
#         tensor(8),
#         tensor(8),
#         tensor(4),
#         tensor(3),
#         tensor(3),
#         tensor(8),
#         tensor(6),
#         tensor(5),
#         tensor(7),
#         tensor(2),
#         tensor(5),
#         tensor(8),
#         tensor(2),
#         tensor(5),
#         tensor(7),
#         tensor(8),
#         tensor(7),
#         tensor(10),
#         tensor(4),
#         tensor(13),
#         tensor(1),
#         tensor(11),
#         tensor(8),
#         tensor(14),
#         tensor(3),
#         tensor(8),
#         tensor(2),
#         tensor(3),
#         tensor(8),
#         tensor(8),
#         tensor(9),
#         tensor(13),
#         tensor(2),
#         tensor(4),
#         tensor(6),
#         tensor(13),
#         tensor(8),
#         tensor(3),
#         tensor(11),
#         tensor(7),
#         tensor(8),
#         tensor(2),
#         tensor(9),
#         tensor(11),
#         tensor(4),
#         tensor(8),
#         tensor(0),
#         tensor(4),
#         tensor(12),
#         tensor(8),
#         tensor(6),
#         tensor(11),
#         tensor(11),
#         tensor(8),
#         tensor(11),
#         tensor(4),
#         tensor(2),
#         tensor(6),
#         tensor(8),
#         tensor(7),
#         tensor(14),
#         tensor(11),
#         tensor(4),
#         tensor(1),
#         tensor(1),
#         tensor(4),
#         tensor(10),
#         tensor(5),
#         tensor(4),
#         tensor(1),
#         tensor(6),
#         tensor(2),
#         tensor(2),
#         tensor(13),
#         tensor(11),
#         tensor(11),
#         tensor(14),
#         tensor(2),
#         tensor(8),
#         tensor(10),
#         tensor(3),
#         tensor(5),
#         tensor(7),
#         tensor(7),
#         tensor(13),
#         tensor(7),
#         tensor(10),
#         tensor(4),
#         tensor(11),
#         tensor(3),
#         tensor(6),
#         tensor(9),
#         tensor(9),
#         tensor(4),
#         tensor(8),
#         tensor(14),
#         tensor(8),
#         tensor(2),
#         tensor(6),
#         tensor(11),
#         tensor(5),
#         tensor(6),
#         tensor(13),
#         tensor(5))
# ic| x: tensor([11,  5, 10,  1, 10,  2,  6,  3, 11,  8,  5,  0, 13,  6,  8,  8, 10,  8,
#                 3, 10, 13,  9,  2,  8,  4,  3,  2, 10,  2,  4,  6,  7,  5,  7,  5,  2,
#                14, 14,  3,  4, 10,  2,  3,  3,  6,  9,  5,  9, 11,  4, 11,  8,  6,  1,
#                11,  6,  4,  8,  7,  8,  8,  2,  4, 13,  4,  5,  2, 11,  7,  4,  8,  7,
#                 2,  2,  8,  3, 14,  6,  3,  5,  2, 13,  2,  2, 11,  6,  9, 13,  2, 13,
#                11,  9,  1,  7,  1,  3,  3, 11,  6,  6,  8, 10,  4,  7, 11,  4,  9,  8,
#                 8,  3,  6, 14,  4,  2, 11,  4, 11,  6,  8,  1,  6,  8,  1,  1, 14,  8,
#                13,  4], dtype=torch.int32)
# ic| y: (tensor(11),
#         tensor(5),
#         tensor(10),
#         tensor(1),
#         tensor(10),
#         tensor(2),
#         tensor(6),
#         tensor(3),
#         tensor(11),
#         tensor(8),
#         tensor(5),
#         tensor(0),
#         tensor(13),
#         tensor(6),
#         tensor(8),
#         tensor(8),
#         tensor(10),
#         tensor(8),
#         tensor(3),
#         tensor(10),
#         tensor(13),
#         tensor(9),
#         tensor(2),
#         tensor(8),
#         tensor(4),
#         tensor(3),
#         tensor(2),
#         tensor(10),
#         tensor(2),
#         tensor(4),
#         tensor(6),
#         tensor(7),
#         tensor(5),
#         tensor(7),
#         tensor(5),
#         tensor(2),
#         tensor(14),
#         tensor(14),
#         tensor(3),
#         tensor(4),
#         tensor(10),
#         tensor(2),
#         tensor(3),
#         tensor(3),
#         tensor(6),
#         tensor(9),
#         tensor(5),
#         tensor(9),
#         tensor(11),
#         tensor(4),
#         tensor(11),
#         tensor(8),
#         tensor(6),
#         tensor(1),
#         tensor(11),
#         tensor(6),
#         tensor(4),
#         tensor(8),
#         tensor(7),
#         tensor(8),
#         tensor(8),
#         tensor(2),
#         tensor(4),
#         tensor(13),
#         tensor(4),
#         tensor(5),
#         tensor(2),
#         tensor(11),
#         tensor(7),
#         tensor(4),
#         tensor(8),
#         tensor(7),
#         tensor(2),
#         tensor(2),
#         tensor(8),
#         tensor(3),
#         tensor(14),
#         tensor(6),
#         tensor(3),
#         tensor(5),
#         tensor(2),
#         tensor(13),
#         tensor(2),
#         tensor(2),
#         tensor(11),
#         tensor(6),
#         tensor(9),
#         tensor(13),
#         tensor(2),
#         tensor(13),
#         tensor(11),
#         tensor(9),
#         tensor(1),
#         tensor(7),
#         tensor(1),
#         tensor(3),
#         tensor(3),
#         tensor(11),
#         tensor(6),
#         tensor(6),
#         tensor(8),
#         tensor(10),
#         tensor(4),
#         tensor(7),
#         tensor(11),
#         tensor(4),
#         tensor(9),
#         tensor(8),
#         tensor(8),
#         tensor(3),
#         tensor(6),
#         tensor(14),
#         tensor(4),
#         tensor(2),
#         tensor(11),
#         tensor(4),
#         tensor(11),
#         tensor(6),
#         tensor(8),
#         tensor(1),
#         tensor(6),
#         tensor(8),
#         tensor(1),
#         tensor(1),
#         tensor(14),
#         tensor(8),
#         tensor(13),
#         tensor(4))
# ic| x: tensor([ 8,  1,  7,  8,  2,  2,  7,  8,  4, 13, 14,  4,  2,  9,  4, 14,  1, 10,
#                10,  4,  9, 11,  1,  5, 13, 10,  7,  7,  6, 10, 13,  9, 14, 14,  0,  1,
#                 9, 11,  2,  3,  4,  4, 13,  5, 13,  8,  4,  4,  1,  9,  3,  1, 13,  9,
#                13, 14,  1,  4,  5,  8,  4, 10,  8,  1, 10, 14, 11,  2,  7, 10, 11,  4,
#                 1,  2,  6,  0,  6,  8,  7,  3,  2,  3,  8, 10, 11, 10,  3,  2, 10,  1,
#                 2, 10,  2, 11,  8, 11,  0,  6, 11,  6,  9,  8,  2,  1,  4,  1, 11, 14,
#                 0,  6,  8,  7, 11,  7,  8,  1,  1,  8,  6,  2,  5,  3,  6,  6, 13, 11,
#                10,  4], dtype=torch.int32)
# ic| y: (tensor(8),
#         tensor(1),
#         tensor(7),
#         tensor(8),
#         tensor(2),
#         tensor(2),
#         tensor(7),
#         tensor(8),
#         tensor(4),
#         tensor(13),
#         tensor(14),
#         tensor(4),
#         tensor(2),
#         tensor(9),
#         tensor(4),
#         tensor(14),
#         tensor(1),
#         tensor(10),
#         tensor(10),
#         tensor(4),
#         tensor(9),
#         tensor(11),
#         tensor(1),
#         tensor(5),
#         tensor(13),
#         tensor(10),
#         tensor(7),
#         tensor(7),
#         tensor(6),
#         tensor(10),
#         tensor(13),
#         tensor(9),
#         tensor(14),
#         tensor(14),
#         tensor(0),
#         tensor(1),
#         tensor(9),
#         tensor(11),
#         tensor(2),
#         tensor(3),
#         tensor(4),
#         tensor(4),
#         tensor(13),
#         tensor(5),
#         tensor(13),
#         tensor(8),
#         tensor(4),
#         tensor(4),
#         tensor(1),
#         tensor(9),
#         tensor(3),
#         tensor(1),
#         tensor(13),
#         tensor(9),
#         tensor(13),
#         tensor(14),
#         tensor(1),
#         tensor(4),
#         tensor(5),
#         tensor(8),
#         tensor(4),
#         tensor(10),
#         tensor(8),
#         tensor(1),
#         tensor(10),
#         tensor(14),
#         tensor(11),
#         tensor(2),
#         tensor(7),
#         tensor(10),
#         tensor(11),
#         tensor(4),
#         tensor(1),
#         tensor(2),
#         tensor(6),
#         tensor(0),
#         tensor(6),
#         tensor(8),IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# tensor(5),
#         tensor(4),
#         tensor(9),
#         tensor(8),
#         tensor(1),
#         tensor(8),
#         tensor(6),
#         tensor(4),
#         tensor(3),
#         tensor(8),
#         tensor(14),
#         tensor(9),
#         tensor(2),
#         tensor(8),
#         tensor(13),
#         tensor(9),
#         tensor(4),
#         tensor(8),
#         tensor(7),
#         tensor(14))
# ic| x: tensor([ 2,  4,  8, 11, 13, 13,  7,  8,  7,  2, 10,  2,  5,  8,  9,  8, 14, 13,
#                 3,  5,  2, 11, 14, 13, 13, 10, 11,  1,  4,  6, 14, 10,  2,  2, 14, 11,
#                 6,  4,  9, 11,  5,  3, 13,  6, 11,  3,  3,  9,  2,  1, 11,  2,  1, 11,
#                 2, 14, 11, 10, 14, 13,  8, 13,  3, 13,  6,  2, 11, 11,  2, 13,  8, 11,
#                 6, 11,  8,  6,  3,  1,  7,  8,  4,  1,  8,  8, 12,  2,  7, 10,  2, 13,
#                 9,  8,  5,  7,  9, 11,  6, 11,  1,  8,  6,  2,  1,  9, 10,  9, 10, 11,
#                 2,  7,  9,  1,  6, 11,  4, 13,  3, 11,  2,  8,  7, 14,  2,  8,  8, 13,
#                 8, 11], dtype=torch.int32)
# ic| y: (tensor(2),
#         tensor(4),
#         tensor(8),
#         tensor(11),
#         tensor(13),
#         tensor(13),
#         tensor(7),
#         tensor(8),
#         tensor(7),
#         tensor(2),
#         tensor(10),
#         tensor(2),
#         tensor(5),
#         tensor(8),
#         tensor(9),
#         tensor(8),
#         tensor(14),
#         tensor(13),
#         tensor(3),
#         tensor(5),
#         tensor(2),
#         tensor(11),
#         tensor(14),
#         tensor(13),
#         tensor(13),
#         tensor(10),
#         tensor(11),
#         tensor(1),
#         tensor(4),
#         tensor(6),
#         tensor(14),
#         tensor(10),
#         tensor(2),
#         tensor(2),
#         tensor(14),
#         tensor(11),
#         tensor(6),
#         tensor(4),
#         tensor(9),
#         tensor(11),
#         tensor(5),
#         tensor(3),
#         tensor(13),
#         tensor(6),
#         tensor(11),
#         tensor(3),
#         tensor(3),
#         tensor(9),
#         tensor(2),
#         tensor(1),
#         tensor(11),
#         tensor(2),
#         tensor(1),
#         tensor(11),
#         tensor(2),
#         tensor(14),
#         tensor(11),
#         tensor(10),
#         tensor(14),
#         tensor(13),
#         tensor(8),
#         tensor(13),
#         tensor(3),
#         tensor(13),
#         tensor(6),
#         tensor(2),
#         tensor(11),
#         tensor(11),
#         tensor(2),
#         tensor(13),
#         tensor(8),
#         tensor(11),
#         tensor(6),
#         tensor(11),
#         tensor(8),
#         tensor(6),
#         tensor(3),
#         tensor(1),
#         tensor(7),
#         tensor(8),
#         tensor(4),
#         tensor(1),
#         tensor(8),
#         tensor(8),
#         tensor(12),
#         tensor(2),
#         tensor(7),
#         tensor(10),
#         tensor(2),
#         tensor(13),
#         tensor(9),
#         tensor(8),
#         tensor(5),
#         tensor(7),
#         tensor(9),
#         tensor(11),
#         tensor(6),
#         tensor(11),
#         tensor(1),
#         tensor(8),
#         tensor(6),
#         tensor(2),
#         tensor(1),
#         tensor(9),
#         tensor(10),
#         tensor(9),
#         tensor(10),
#         tensor(11),
#         tensor(2),
#         tensor(7),
#         tensor(9),
#         tensor(1),
#         tensor(6),
#         tensor(11),
#         tensor(4),
#         tensor(13),
#         tensor(3),
#         tensor(11),
#         tensor(2),
#         tensor(8),
#         tensor(7),
#         tensor(14),
#         tensor(2),
#         tensor(8),
#         tensor(8),
#         tensor(13),
#         tensor(8),
#         tensor(11))
# ic| x: tensor([ 2,  8,  1,  8,  4,  4,  2,  5,  2,  6, 14,  1, 11, 13,  8, 11,  3,  9,
#                13, 10, 11, 14,  4,  4,  3,  6,  6,  7,  6, 11, 13,  7,  7, 11,  7,  8,
#                 7,  8,  8,  0,  9,  6,  9,  0, 14, 13,  3,  6,  0,  1,  4,  1, 14,  9,
#                 7,  8, 10,  1,  1, 14,  9,  9,  3, 10,  4, 13,  9,  8, 11, 10,  6,  2,
#                11,  7,  1, 13,  1,  1,  1,  8, 14,  4,  8,  3, 14,  7,  2, 14, 11,  7,
#                 0, 11,  4,  1,  7,  6, 13,  9, 14,  4,  8,  8, 11,  1, 14,  7,  6,  3,
#                 6,  9,  2, 11,  4, 11,  5,  4, 14,  3,  9, 11,  7,  1, 14,  3,  1, 11,
#                14,  6], dtype=torch.int32)
# ic| y: (tensor(2),
#         tensor(8),
#         tensor(1),
#         tensor(8),
#         tensor(4),
#         tensor(4),
#         tensor(2),
#         tensor(5),
#         tensor(2),
#         tensor(6),
#         tensor(14),
#         tensor(1),
#         tensor(11),
#         tensor(13),
#         tensor(8),
#         tensor(11),
#         tensor(3),
#         tensor(9),
#         tensor(13),
#         tensor(10),
#         tensor(11),
#         tensor(14),
#         tensor(4),
#         tensor(4),
#         tensor(3),
#         tensor(6),
#         tensor(6),
#         tensor(7),
#         tensor(6),
#         tensor(11),
#         tensor(13),
#         tensor(7),
#         tensor(7),
#         tensor(11),
#         tensor(7),
#         tensor(8),
#         tensor(7),
#         tensor(8),
#         tensor(8),
#         tensor(0),
#         tensor(9),
#         tensor(6),
#         tensor(9),
#         tensor(0),
#         tensor(14),
#         tensor(13),
#         tensor(3),
#         tensor(6),
#         tensor(0),
#         tensor(1),
#         tensor(4),
#         tensor(1),
#         tensor(14),
#         tensor(9),
#         tensor(7),
#         tensor(8),
#         tensor(10),
#         tensor(1),
#         tensor(1),
#         tensor(14),
#         tensor(9),
#         tensor(9),
#         tensor(3),
#         tensor(10),
#         tensor(4),
#         tensor(13),
#         tensor(9),
#         tensor(8),
#         tensor(11),
#         tensor(10),
#         tensor(6),
#         tensor(2),
#         tensor(11),
#         tensor(7),
#         tensor(1),
#         tensor(13),
#         tensor(1),
#         tensor(1),
#         tensor(1),
#         tensor(8),
#         tensor(14),
#         tensor(4),
#         tensor(8),
#         tensor(3),
#         tensor(14),
#         tensor(7),
#         tensor(2),
#         tensor(14),
#         tensor(11),
#         tensor(7),
#         tensor(0),
#         tensor(11),
#         tensor(4),
#         tensor(1),
#         tensor(7),
#         tensor(6),
#         tensor(13),
#         tensor(9),
#         tensor(14),
#         tensor(4),
#         tensor(8),
#         tensor(8),
#         tensor(11),
#         tensor(1),
#         tensor(14),
#         tensor(7),
#         tensor(6),
#         tensor(3),
#         tensor(6),
#         tensor(9),
#         tensor(2),
#         tensor(11),
#         tensor(4),
#         tensor(11),
#         tensor(5),
#         tensor(4),
#         tensor(14),
#         tensor(3),
#         tensor(9),
#         tensor(11),
#         tensor(7),
#         tensor(1),
#         tensor(14),
#         tensor(3),
#         tensor(1),
#         tensor(11),
#         tensor(14),
#         tensor(6))
# ic| x: tensor([13,  0,  1,  6,  4,  9,  4,  2, 10, 11,  6,  2, 11,  8,  7, 14,  4,  8,
#                 3,  7,  6,  8,  9, 14,  5, 10,  4, 14, 13, 14,  3,  6,  4, 11, 11,  7,
#                 4, 11,  1,  7,  1,  6, 11, 12,  5,  8,  8,  4,  6,  8, 11,  8,  3,  9,
#                11,  9,  2,  8,  9,  7,  0,  3,  2,  3,  8, 11,  2,  8, 10,  3,  4, 11,
#                11,  9,  2, 10IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#
#         tensor(8),
#         tensor(3),
#         tensor(13),
#         tensor(4),
#         tensor(4),
#         tensor(10),
#         tensor(8),
#         tensor(13),
#         tensor(8),
#         tensor(2),
#         tensor(9),
#         tensor(14),
#         tensor(14),
#         tensor(13),
#         tensor(11),
#         tensor(9),
#         tensor(14),
#         tensor(11),
#         tensor(13),
#         tensor(8),
#         tensor(3),
#         tensor(14),
#         tensor(7),
#         tensor(5),
#         tensor(8),
#         tensor(4),
#         tensor(3),
#         tensor(14),
#         tensor(1),
#         tensor(9),
#         tensor(11),
#         tensor(5),
#         tensor(2),
#         tensor(7),
#         tensor(11),
#         tensor(1),
#         tensor(7),
#         tensor(7),
#         tensor(1),
#         tensor(6),
#         tensor(11),
#         tensor(0),
#         tensor(13),
#         tensor(3),
#         tensor(8),
#         tensor(6),
#         tensor(6),
#         tensor(2),
#         tensor(9),
#         tensor(2),
#         tensor(11),
#         tensor(6),
#         tensor(8),
#         tensor(2),
#         tensor(11),
#         tensor(9),
#         tensor(11),
#         tensor(4),
#         tensor(10),
#         tensor(7),
#         tensor(3),
#         tensor(11),
#         tensor(3),
#         tensor(8),
#         tensor(10),
#         tensor(3),
#         tensor(6),
#         tensor(5),
#         tensor(14),
#         tensor(6),
#         tensor(5),
#         tensor(1),
#         tensor(1),
#         tensor(1),
#         tensor(1),
#         tensor(0),
#         tensor(7),
#         tensor(14),
#         tensor(10),
#         tensor(4),
#         tensor(2),
#         tensor(3),
#         tensor(8),
#         tensor(6),
#         tensor(7),
#         tensor(2))
# ic| x: tensor([ 6,  1, 10,  1,  3,  4,  1, 11, 13,  8, 10,  8,  8, 11,  9,  5,  3,  1,
#                 6,  2,  4,  2,  1,  2,  9,  2,  3,  8, 10, 14,  2, 11,  2,  3,  8,  6,
#                10,  9,  2,  9,  9,  7, 11,  7,  7,  4,  1,  3,  8,  9,  8,  7,  8, 13,
#                 9,  4,  4,  5,  1,  4,  5,  4, 13,  6,  8, 11, 14,  6,  6,  7,  6, 13,
#                 4,  2,  6,  3,  6,  6, 11,  2, 13,  8, 10,  1,  8,  3,  9,  1,  8, 10,
#                10,  1,  0, 14,  3,  8,  6,  0, 10,  6,  7,  1,  2,  2, 11, 14,  3,  9,
#                 8, 14,  4,  8,  3,  5,  8, 13,  9, 13, 10,  1,  4,  3,  7,  5,  4,  6,
#                11,  4], dtype=torch.int32)
# ic| y: (tensor(6),
#         tensor(1),
#         tensor(10),
#         tensor(1),
#         tensor(3),
#         tensor(4),
#         tensor(1),
#         tensor(11),
#         tensor(13),
#         tensor(8),
#         tensor(10),
#         tensor(8),
#         tensor(8),
#         tensor(11),
#         tensor(9),
#         tensor(5),
#         tensor(3),
#         tensor(1),
#         tensor(6),
#         tensor(2),
#         tensor(4),
#         tensor(2),
#         tensor(1),
#         tensor(2),
#         tensor(9),
#         tensor(2),
#         tensor(3),
#         tensor(8),
#         tensor(10),
#         tensor(14),
#         tensor(2),
#         tensor(11),
#         tensor(2),
#         tensor(3),
#         tensor(8),
#         tensor(6),
#         tensor(10),
#         tensor(9),
#         tensor(2),
#         tensor(9),
#         tensor(9),
#         tensor(7),
#         tensor(11),
#         tensor(7),
#         tensor(7),
#         tensor(4),
#         tensor(1),
#         tensor(3),
#         tensor(8),
#         tensor(9),
#         tensor(8),
#         tensor(7),
#         tensor(8),
#         tensor(13),
#         tensor(9),
#         tensor(4),
#         tensor(4),
#         tensor(5),
#         tensor(1),
#         tensor(4),
#         tensor(5),
#         tensor(4),
#         tensor(13),
#         tensor(6),
#         tensor(8),
#         tensor(11),
#         tensor(14),
#         tensor(6),
#         tensor(6),
#         tensor(7),
#         tensor(6),
#         tensor(13),
#         tensor(4),
#         tensor(2),
#         tensor(6),
#         tensor(3),
#         tensor(6),
#         tensor(6),
#         tensor(11),
#         tensor(2),
#         tensor(13),
#         tensor(8),
#         tensor(10),
#         tensor(1),
#         tensor(8),
#         tensor(3),
#         tensor(9),
#         tensor(1),
#         tensor(8),
#         tensor(10),
#         tensor(10),
#         tensor(1),
#         tensor(0),
#         tensor(14),
#         tensor(3),
#         tensor(8),
#         tensor(6),
#         tensor(0),
#         tensor(10),
#         tensor(6),
#         tensor(7),
#         tensor(1),
#         tensor(2),
#         tensor(2),
#         tensor(11),
#         tensor(14),
#         tensor(3),
#         tensor(9),
#         tensor(8),
#         tensor(14),
#         tensor(4),
#         tensor(8),
#         tensor(3),
#         tensor(5),
#         tensor(8),
#         tensor(13),
#         tensor(9),
#         tensor(13),
#         tensor(10),
#         tensor(1),
#         tensor(4),
#         tensor(3),
#         tensor(7),
#         tensor(5),
#         tensor(4),
#         tensor(6),
#         tensor(11),
#         tensor(4))
